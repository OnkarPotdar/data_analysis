# %%
import pandas as pd
import numpy as np

# %%
exp_salary = pd.read_csv('D:/onkar_cdac/C-DAC/PML-20230313T171418Z-001/PML/Files_by_sir/5. PML/1. Day wise Study Material/Datasets/Exp_Salaries.csv')
exp_salary
# Out:
#     Salary  Years_Previous_Experience  Years_Employed  Years_Education  \
# 0    32782                          1               0                7
# 1    32920                          3              15                9
# 2    29548                          6               5                1
# 3    39828                          6              18                5
# 4    31528                         11               3                3
# 5    38985                          7              18                9
# 6    41889                         16              22                7
# 7    38791                          4              21                5
# 8    28985                          1               0                4
# 9    24749                          2               6                0
# 10   35467                          6               3                6
# 11   35468                          5               9                4
# ...

# %%
print(exp_salary.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 46 entries, 0 to 45
# Data columns (total 7 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   Salary                     46 non-null     int64
#  1   Years_Previous_Experience  46 non-null     int64
#  2   Years_Employed             46 non-null     int64
#  3   Years_Education            46 non-null     int64
#  4   Gender                     46 non-null     object
#  5   Department                 46 non-null     object
#  6   Number_Supervised          46 non-null     int64
# dtypes: int64(5), object(2)
# memory usage: 2.6+ KB
# None

# %%
dum_exp = pd.get_dummies(exp_salary, drop_first=True)

# %%
dum_exp
# Out:
#     Salary  Years_Previous_Experience  Years_Employed  Years_Education  \
# 0    32782                          1               0                7
# 1    32920                          3              15                9
# 2    29548                          6               5                1
# 3    39828                          6              18                5
# 4    31528                         11               3                3
# 5    38985                          7              18                9
# 6    41889                         16              22                7
# 7    38791                          4              21                5
# 8    28985                          1               0                4
# 9    24749                          2               6                0
# 10   35467                          6               3                6
# 11   35468                          5               9                4
# ...

# %%
dum_exp.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 46 entries, 0 to 45
# Data columns (total 9 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   Salary                     46 non-null     int64
#  1   Years_Previous_Experience  46 non-null     int64
#  2   Years_Employed             46 non-null     int64
#  3   Years_Education            46 non-null     int64
#  4   Number_Supervised          46 non-null     int64
#  5   Gender_Male                46 non-null     uint8
#  6   Department_B               46 non-null     uint8
#  7   Department_C               46 non-null     uint8
#  8   Department_D               46 non-null     uint8
# dtypes: int64(5), uint8(4)
# memory usage: 2.1 KB

# %%
exp_salary.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 46 entries, 0 to 45
# Data columns (total 7 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   Salary                     46 non-null     int64
#  1   Years_Previous_Experience  46 non-null     int64
#  2   Years_Employed             46 non-null     int64
#  3   Years_Education            46 non-null     int64
#  4   Gender                     46 non-null     object
#  5   Department                 46 non-null     object
#  6   Number_Supervised          46 non-null     int64
# dtypes: int64(5), object(2)
# memory usage: 2.6+ KB

# %%
jobsal = pd.read_csv('D:/onkar_cdac/C-DAC/PML-20230313T171418Z-001/PML/Files_by_sir/5. PML/1. Day wise Study Material/Datasets/JobSalary2.csv')
jobsal
# Out:
#    S_No  Computer  Marketing  Engineer
# 0     1      84.0       55.0        75
# 1     2      90.0       53.0        70
# 2     3      63.0        NaN        88
# 3     4       NaN       50.0        77
# 4     5      63.0       41.0        89
# 5     6      75.0       54.0        85
# 6     7       NaN       51.0        96
# 7     8      77.0       64.0       105

# %%
# Count the NAs in each column
jobsal.isnull().sum()
# Out:
# S_No         0
# Computer     2
# Marketing    1
# Engineer     0
# dtype: int64

# %%
# Total NAs
jobsal.isnull().sum().sum()
# Out:
# 3

# %%
# Dropping NA rows
jobsal.dropna()
# Out:
#    S_No  Computer  Marketing  Engineer
# 0     1      84.0       55.0        75
# 1     2      90.0       53.0        70
# 4     5      63.0       41.0        89
# 5     6      75.0       54.0        85
# 7     8      77.0       64.0       105

# %%
from sklearn.impute import SimpleImputer
# Constant Imputation
imputer = SimpleImputer(strategy="constant",fill_value=50)
imp_data=imputer.fit_transform(jobsal)
imp_pd_data = pd.DataFrame(imp_data, columns=jobsal.columns)

# %%
imp_pd_data
# Out:
#    S_No  Computer  Marketing  Engineer
# 0   1.0      84.0       55.0      75.0
# 1   2.0      90.0       53.0      70.0
# 2   3.0      63.0       50.0      88.0
# 3   4.0      50.0       50.0      77.0
# 4   5.0      63.0       41.0      89.0
# 5   6.0      75.0       54.0      85.0
# 6   7.0      50.0       51.0      96.0
# 7   8.0      77.0       64.0     105.0

# %%
# Mean Imputation
imputer = SimpleImputer(strategy="mean")
imp_data=imputer.fit_transform(jobsal)
imp_pd_data = pd.DataFrame(imp_data, columns=jobsal.columns)

# %%
# Median Imputation
imputer = SimpleImputer(strategy="median")
imp_data=imputer.fit_transform(jobsal)
imp_pd_data = pd.DataFrame(imp_data, columns=jobsal.columns)

# %%
### Chem Proc
chem = pd.read_csv('D:/onkar_cdac/C-DAC/PML-20230313T171418Z-001/PML/Files_by_sir/5. PML/1. Day wise Study Material/Datasets/ChemicalProcess.csv')
chem
# Out:
#      Yield  BiologicalMaterial01  BiologicalMaterial02  BiologicalMaterial03  \
# 0    38.00                  6.25                 49.58                 56.97
# 1    42.44                  8.01                 60.97                 67.48
# 2    42.03                  8.01                 60.97                 67.48
# 3    41.42                  8.01                 60.97                 67.48
# 4    42.49                  7.47                 63.33                 72.25
# ..     ...                   ...                   ...                   ...
# 171  39.66                  6.71                 56.32                 66.19
# 172  39.68                  6.87                 56.74                 66.61
# 173  42.23                  7.50                 58.41                 68.30
# 174  38.48                  7.53                 58.36                 69.25
# 175  39.49                  7.53                 58.36                 69.25
#
# ...

# %%
chem.isnull().sum()
# Out:
# Yield                      0
# BiologicalMaterial01       0
# BiologicalMaterial02       0
# BiologicalMaterial03       0
# BiologicalMaterial04       0
# BiologicalMaterial05       0
# BiologicalMaterial06       0
# BiologicalMaterial07       0
# BiologicalMaterial08       0
# BiologicalMaterial09       0
# BiologicalMaterial10       0
# BiologicalMaterial11       0
# BiologicalMaterial12       0
# ManufacturingProcess01     1
# ManufacturingProcess02     3
# ManufacturingProcess03    15
# ManufacturingProcess04     1
# ManufacturingProcess05     1
# ManufacturingProcess06     2
# ManufacturingProcess07     1
# ManufacturingProcess08     1
# ManufacturingProcess09     0
# ManufacturingProcess10     9
# ManufacturingProcess11    10
# ManufacturingProcess12     1
# ManufacturingProcess13     0
# ManufacturingProcess14     1
# ManufacturingProcess15     0
# ManufacturingProcess16     0
# ManufacturingProcess17     0
# ManufacturingProcess18     0
# ManufacturingProcess19     0
# ...

# %%
chem.isnull().sum().sum()
# Out:
# 106

# %%
# Median Imputation
imputer = SimpleImputer(strategy="median")
imp_data=imputer.fit_transform(chem)
imp_pd_data = pd.DataFrame(imp_data, columns=chem.columns)

imp_pd_data.isnull().sum().sum()
# Out:
# 0

# %%
########## Scaling
from sklearn.preprocessing import StandardScaler, MinMaxScaler

milk = pd.read_csv("D:/onkar_cdac/C-DAC/PML-20230313T171418Z-001/PML/Files_by_sir/5. PML/1. Day wise Study Material/Datasets/milk.csv", index_col=0)
milk
# Out:
#             water  protein   fat  lactose   ash
# Animal
# HORSE        90.1      2.6   1.0      6.9  0.35
# ORANGUTAN    88.5      1.4   3.5      6.0  0.24
# MONKEY       88.4      2.2   2.7      6.4  0.18
# DONKEY       90.3      1.7   1.4      6.2  0.40
# HIPPO        90.4      0.6   4.5      4.4  0.10
# CAMEL        87.7      3.5   3.4      4.8  0.71
# BISON        86.9      4.8   1.7      5.7  0.90
# BUFFALO      82.1      5.9   7.9      4.7  0.78
# GUINEA PIG   81.9      7.4   7.2      2.7  0.85
# CAT          81.6     10.1   6.3      4.4  0.75
# FOX          81.6      6.6   5.9      4.9  0.93
# LLAMA        86.5      3.9   3.2      5.6  0.80
# MULE         90.0      2.0   1.8      5.5  0.47
# PIG          82.8      7.1   5.1      3.7  1.10
# ZEBRA        86.2      3.0   4.8      5.3  0.70
# SHEEP        82.0      5.6   6.4      4.7  0.91
# DOG          76.3      9.3   9.5      3.0  1.20
# ELEPHANT     70.7      3.6  17.6      5.6  0.63
# ...

# %%
# Standard Scaler
scl_std = StandardScaler()
scl_std.fit(milk)
# Out:
# StandardScaler()

# %%
# Means
print(scl_std.mean_)
# Out:
# [78.184   6.212  10.308   4.132   0.8632]

# %%
# Std Dev
print(scl_std.scale_)
# Out:
# [12.55893881  3.57875062 10.30549058  1.79481921  0.49462487]

# %%
trns_scl = scl_std.transform(milk)
# or
trns_scl = scl_std.fit_transform(milk)
type(trns_scl)
# Out:
# numpy.ndarray

# %%
trns_scl_pd = pd.DataFrame(trns_scl,columns=milk.columns,
                           index=milk.index)

# %%
trns_scl_pd.mean()
# Out:
# water     -9.059420e-16
# protein    1.332268e-16
# fat       -3.552714e-17
# lactose   -3.996803e-16
# ash        3.996803e-17
# dtype: float64

# %%
trns_scl_pd.std()
# Out:
# water      1.020621
# protein    1.020621
# fat        1.020621
# lactose    1.020621
# ash        1.020621
# dtype: float64

# %%
# MinMax Scaler
scl_mm = MinMaxScaler()
scl_mm.fit(milk)
# Out:
# MinMaxScaler()

# %%
# Min
print(scl_mm.data_min_)
# Out:
# [44.9  0.6  1.   0.   0.1]

# %%
# Max
print(scl_mm.data_max_)
# Out:
# [90.4 12.3 42.   6.9  2.3]

# %%
trns_scl = scl_mm.transform(milk)
# or
trns_scl = scl_mm.fit_transform(milk)
type(trns_scl)
# Out:
# numpy.ndarray

# %%
trns_scl_pd = pd.DataFrame(trns_scl,columns=milk.columns,
                           index=milk.index)

trns_scl_pd.min()
trns_scl_pd.max()
# Out:
# water      1.0
# protein    1.0
# fat        1.0
# lactose    1.0
# ash        1.0
# dtype: float64

# %%
import seaborn as sns
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split

# %%
hr = pd.read_csv("D:/onkar_cdac/C-DAC/PML-20230313T171418Z-001/PML/Files_by_sir/5. PML/1. Day wise Study Material/Cases/human-resources-analytics/HR_comma_sep.csv")
hr
# Out:
#        satisfaction_level  last_evaluation  number_project  \
# 0                    0.38             0.53               2
# 1                    0.80             0.86               5
# 2                    0.11             0.88               7
# 3                    0.72             0.87               5
# 4                    0.37             0.52               2
# ...                   ...              ...             ...
# 14994                0.40             0.57               2
# 14995                0.37             0.48               2
# 14996                0.37             0.53               2
# 14997                0.11             0.96               6
# 14998                0.37             0.52               2
#
#        average_montly_hours  time_spend_company  Work_accident  left  \
# 0                       157                   3              0     1
# 1                       262                   6              0     1
# ...

# %%
dum_hr = pd.get_dummies(hr, drop_first=True)
dum_hr
# Out:
#        satisfaction_level  last_evaluation  number_project  \
# 0                    0.38             0.53               2
# 1                    0.80             0.86               5
# 2                    0.11             0.88               7
# 3                    0.72             0.87               5
# 4                    0.37             0.52               2
# ...                   ...              ...             ...
# 14994                0.40             0.57               2
# 14995                0.37             0.48               2
# 14996                0.37             0.53               2
# 14997                0.11             0.96               6
# 14998                0.37             0.52               2
#
#        average_montly_hours  time_spend_company  Work_accident  left  \
# 0                       157                   3              0     1
# 1                       262                   6              0     1
# ...

# %%
X = dum_hr.drop('left',axis=1)
y = dum_hr['left']

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y,random_state=2022,
                                                    test_size=0.3,
                                                    stratify=y)

# %%
from sklearn.neighbors import KNeighborsClassifier
from sklearn.metrics import accuracy_score, roc_auc_score
from sklearn.preprocessing import StandardScaler, MinMaxScaler

# %%
scaler = StandardScaler()
scl_trn = scaler.fit_transform(X_train)
scl_tst = scaler.transform(X_test)

# %%
knn = KNeighborsClassifier(n_neighbors=13)
knn.fit(scl_trn, y_train)
# Out:
# KNeighborsClassifier(n_neighbors=13)

# %%
# ROC AUC
y_pred_prob = knn.predict_proba(scl_tst)[:,1]
print(roc_auc_score(y_test, y_pred_prob))
# Out:
# 0.9684614586575371
