# %%
import pandas as pd
import numpy as np
from sklearn.model_selection import cross_val_score, StratifiedKFold
from sklearn.neighbors import KNeighborsClassifier

# %%
b_cancer=pd.read_csv("D:/onkar_cdac/C-DAC/PML/PML/Files_by_sir/5. PML/1. Day wise Study Material/Cases/Wisconsin/BreastCancer.csv")

# %%
b_cancer
# Out:
#          Code  Clump  UniCell_Size  Uni_CellShape  MargAdh  SEpith  BareN  \
# 0       61634      5             4              3        1       2      2
# 1       63375      9             1              2        6       4     10
# 2       76389     10             4              7        2       2      8
# 3       95719      6            10             10       10       8     10
# 4      128059      1             1              1        1       2      5
# ..        ...    ...           ...            ...      ...     ...    ...
# 694   1369821     10            10             10       10       5     10
# 695   1371026      5            10             10       10       4     10
# 696   1371920      5             1              1        1       2      1
# 697   8233704      4             1              1        1       1      1
# 698  13454352      1             1              3        1       2      1
#
#      BChromatin  NoemN  Mitoses      Class
# ...

# %%
dum_b_cancer = pd.get_dummies(b_cancer, drop_first=True)
X = dum_b_cancer.drop('Class_Malignant',axis=1)
y = dum_b_cancer['Class_Malignant']

# %%
kfold = StratifiedKFold(n_splits=5, shuffle=True, random_state=2023)
knn = KNeighborsClassifier(n_neighbors=3)
results = cross_val_score(knn, X, y ,scoring='roc_auc',
                          cv = kfold)
print(results)
print(results.mean())
# Out:
# [0.64617301 0.51890851 0.5951087  0.53790087 0.5157967 ]
# 0.5627775590647153

# %%
roc = []
ks = np.arange(1,30,2)
for i in ks:
    knn = KNeighborsClassifier(n_neighbors=i)
    results = cross_val_score(knn, X, y ,scoring='roc_auc',
                              cv = kfold)
    roc.append(results.mean())

i_max = np.argmax(roc)
print("Best k =", ks[i_max], "with score =", np.max(roc))
# Out:
# Best k = 15 with score = 0.6102817163057292

# %%
df=pd.read_csv('D:/onkar_cdac/C-DAC/PML/PML/Files_by_sir/5. PML/1. Day wise Study Material/Cases/human-resources-analytics/HR_comma_sep.csv')

# %%
df
# Out:
#        satisfaction_level  last_evaluation  number_project  \
# 0                    0.38             0.53               2
# 1                    0.80             0.86               5
# 2                    0.11             0.88               7
# 3                    0.72             0.87               5
# 4                    0.37             0.52               2
# ...                   ...              ...             ...
# 14994                0.40             0.57               2
# 14995                0.37             0.48               2
# 14996                0.37             0.53               2
# 14997                0.11             0.96               6
# 14998                0.37             0.52               2
#
#        average_montly_hours  time_spend_company  Work_accident  left  \
# 0                       157                   3              0     1
# 1                       262                   6              0     1
# ...

# %%
dum_df = pd.get_dummies(df, drop_first=True)
X = dum_df.drop('left',axis=1)
y = dum_df['left']

# %%
kfold = StratifiedKFold(n_splits=5, shuffle=True, random_state=2023)

# %%
roc = []
ks = np.arange(1,30,2)
for i in ks:
    knn = KNeighborsClassifier(n_neighbors=i)
    results = cross_val_score(knn, X, y ,scoring='roc_auc',
                              cv = kfold)
    roc.append(results.mean())

i_max = np.argmax(roc)
print("Best k =", ks[i_max], "with score =", np.max(roc))
# Out:
# Best k = 7 with score = 0.9743020379383627

# %%
############### Grid Search CV

# %%
from sklearn.model_selection import GridSearchCV

# %%
b_cancer=pd.read_csv('D:/onkar_cdac/C-DAC/PML/PML/Files_by_sir/5. PML/1. Day wise Study Material/Cases/Wisconsin/BreastCancer.csv')

# %%
b_cancer
# Out:
#          Code  Clump  UniCell_Size  Uni_CellShape  MargAdh  SEpith  BareN  \
# 0       61634      5             4              3        1       2      2
# 1       63375      9             1              2        6       4     10
# 2       76389     10             4              7        2       2      8
# 3       95719      6            10             10       10       8     10
# 4      128059      1             1              1        1       2      5
# ..        ...    ...           ...            ...      ...     ...    ...
# 694   1369821     10            10             10       10       5     10
# 695   1371026      5            10             10       10       4     10
# 696   1371920      5             1              1        1       2      1
# 697   8233704      4             1              1        1       1      1
# 698  13454352      1             1              3        1       2      1
#
#      BChromatin  NoemN  Mitoses      Class
# ...

# %%
dum_b_cancer = pd.get_dummies(b_cancer, drop_first=True)
X = dum_b_cancer.drop('Class_Malignant',axis=1)
y = dum_b_cancer['Class_Malignant']

# %%
kfold = StratifiedKFold(n_splits=5, shuffle=True, random_state=2023)
knn = KNeighborsClassifier()

# %%
params = {'n_neighbors':np.arange(1,30,2)}
gcv = GridSearchCV(knn, param_grid=params,scoring='roc_auc',
                          cv = kfold, verbose=3)

# %%
gcv.fit(X, y)
print(gcv.best_params_)
print(gcv.best_score_)

pd_gcv = pd.DataFrame(gcv.cv_results_)
# Out:
# Fitting 5 folds for each of 15 candidates, totalling 75 fits
# [CV 1/5] END .....................n_neighbors=1;, score=0.582 total time=   0.0s
# [CV 2/5] END .....................n_neighbors=1;, score=0.557 total time=   0.0s
# [CV 3/5] END .....................n_neighbors=1;, score=0.645 total time=   0.0s
# [CV 4/5] END .....................n_neighbors=1;, score=0.530 total time=   0.0s
# [CV 5/5] END .....................n_neighbors=1;, score=0.594 total time=   0.0s
# [CV 1/5] END .....................n_neighbors=3;, score=0.646 total time=   0.0s
# [CV 2/5] END .....................n_neighbors=3;, score=0.519 total time=   0.0s
# [CV 3/5] END .....................n_neighbors=3;, score=0.595 total time=   0.0s
# [CV 4/5] END .....................n_neighbors=3;, score=0.538 total time=   0.0s
# [CV 5/5] END .....................n_neighbors=3;, score=0.516 total time=   0.0s
# [CV 1/5] END .....................n_neighbors=5;, score=0.623 total time=   0.0s
# ...

# %%
############### Image Segementation

# %%
from sklearn.preprocessing import LabelEncoder
from sklearn.pipeline import Pipeline
from sklearn.preprocessing import StandardScaler

# %%
imag_seg = pd.read_csv('D:/onkar_cdac/C-DAC/PML/PML/Files_by_sir/5. PML/1. Day wise Study Material/Cases/Image Segmentation/Image_Segmention.csv')

# %%
imag_seg
# Out:
#          Class  region.centroid.col  region.centroid.row  region.pixel.count  \
# 0    BRICKFACE                  188                  133                   9
# 1    BRICKFACE                  105                  139                   9
# 2    BRICKFACE                   34                  137                   9
# 3    BRICKFACE                   39                  111                   9
# 4    BRICKFACE                   16                  128                   9
# ..         ...                  ...                  ...                 ...
# 204      GRASS                   36                  243                   9
# 205      GRASS                  186                  218                   9
# 206      GRASS                  197                  236                   9
# 207      GRASS                  208                  240                   9
# 208      GRASS                  223                  185                   9
#
# ...

# %%
X = imag_seg.drop('Class', axis=1)
y = imag_seg['Class']

# %%
le = LabelEncoder()
le_y = le.fit_transform(y)
print(le.classes_)
# Out:
# ['BRICKFACE' 'CEMENT' 'FOLIAGE' 'GRASS' 'PATH' 'SKY' 'WINDOW']

# %%
kfold = StratifiedKFold(n_splits=5, shuffle=True, random_state=2023)

# %%
scaler = StandardScaler()
knn = KNeighborsClassifier()
pipe = Pipeline([('scl_std', scaler), ('knn_model', knn)])

# %%
params = {'knn_model__n_neighbors':np.arange(1,31)}
gcv = GridSearchCV(pipe, param_grid=params,scoring='neg_log_loss',
                          cv = kfold)

# %%
gcv.fit(X, y)
print(gcv.best_params_)
print(gcv.best_score_)

pd_gcv = pd.DataFrame(gcv.cv_results_)
# Out:
# {'knn_model__n_neighbors': 19}
# -0.7103594622824053
